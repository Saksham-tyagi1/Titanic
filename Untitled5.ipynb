# %% [markdown]
# <a href="https://colab.research.google.com/github/Saksham-tyagi1/Titanic/blob/Titatin/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-293c414c-ef15-40d7-9fc6-e7947ebe925a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-293c414c-ef15-40d7-9fc6-e7947ebe925a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
plt.figure(figsize=(10,3))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Sex',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Pclass',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='SibSp',data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
df['Fare'].hist()
# Out:
# <Axes: >

# %%
sns.countplot(x='Embarked',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
plt.figure(figsize=(11,4))
sns.boxplot(x='Pclass',y='Age',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna('S', inplace=True)
df.drop(columns=['Cabin'], errors='ignore', inplace=True)


print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
sex = pd.get_dummies(df['Sex'],drop_first=True)
embarked = pd.get_dummies(df['Embarked'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-c3b96af9f5b0> in <cell line: 1>()
# ----> 1 sex = pd.get_dummies(df['Sex'],drop_first=True)
# ...

# %%
df.drop(columns=['PassengerId','Name','Sex','Ticket','Embarked'],inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
df = pd.concat([df,sex,embarked],axis=1)
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0         0       3  22.0      1      0   7.2500   True  False   True
# 1         1       1  38.0      1      0  71.2833  False  False  False
# 2         1       3  26.0      0      0   7.9250  False  False   True
# 3         1       1  35.0      1      0  53.1000  False  False   True
# 4         0       3  35.0      0      0   8.0500   True  False   True
